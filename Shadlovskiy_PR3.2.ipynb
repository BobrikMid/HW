# %% [markdown]
# ## ПРАКТИЧНА РОБОТА 3_2
# ### Тема: "Візуалізація даних з використанням бібліотеки Seaborn"

# %%
import pandas as pd
df = pd.read_csv("C:/Users/faika/OneDrive/Desktop/shopping_trends.csv", encoding="latin1")

# %%
df.shape
# Out:
#    customer_id  age gender item_purchased  category  purchase_amount_(usd)  \
# 0            1   55   Male         Blouse  Clothing                     53
# 1            2   19   Male        Sweater  Clothing                     64
# 2            3   50   Male          Jeans  Clothing                     73
# 3            4   21   Male        Sandals  Footwear                     90
# 4            5   45   Male         Blouse  Clothing                     49
#
#         location size      color  season  review_rating subscription_status  \
# 0       Kentucky    L       Gray  Winter            3.1                 Yes
# 1          Maine    L     Maroon  Winter            3.1                 Yes
# 2  Massachusetts    S     Maroon  Spring            3.1                 Yes
# 3   Rhode Island    M     Maroon  Spring            3.5                 Yes
# 4         Oregon    M  Turquoise  Spring            2.7                 Yes
#
# ...

# %%
df.isnull().sum()
# Out:
# customer_id                 0
# age                         0
# gender                      0
# item_purchased              0
# category                    0
# purchase_amount_(usd)       0
# location                    0
# size                        0
# color                       0
# season                      0
# review_rating               0
# subscription_status         0
# payment_method              0
# shipping_type               0
# discount_applied            0
# promo_code_used             0
# previous_purchases          0
# preferred_payment_method    0
# frequency_of_purchases      0
# dtype: int64

# %%
df.dtypes
# Out:
# customer_id                   int64
# age                           int64
# gender                       object
# item_purchased               object
# category                     object
# purchase_amount_(usd)         int64
# location                     object
# size                         object
# color                        object
# season                       object
# review_rating               float64
# subscription_status          object
# payment_method               object
# shipping_type                object
# discount_applied             object
# promo_code_used              object
# previous_purchases            int64
# preferred_payment_method     object
# frequency_of_purchases       object
# dtype: object

# %%
df = df.rename(columns=lambda x: x.lower().replace(' ', '_'))

# %%
df.head()
# Out:
#    customer_id  age gender item_purchased  category  purchase_amount_(usd)  \
# 0            1   55   Male         Blouse  Clothing                     53
# 1            2   19   Male        Sweater  Clothing                     64
# 2            3   50   Male          Jeans  Clothing                     73
# 3            4   21   Male        Sandals  Footwear                     90
# 4            5   45   Male         Blouse  Clothing                     49
#
#         location size      color  season  review_rating subscription_status  \
# 0       Kentucky    L       Gray  Winter            3.1                 Yes
# 1          Maine    L     Maroon  Winter            3.1                 Yes
# 2  Massachusetts    S     Maroon  Spring            3.1                 Yes
# 3   Rhode Island    M     Maroon  Spring            3.5                 Yes
# 4         Oregon    M  Turquoise  Spring            2.7                 Yes
#
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.set(style="whitegrid") 
plt.figure(figsize=(10, 6))  
sns.histplot(data=df, x='age', bins=20, kde=True, color='skyblue')
plt.title('Гістограма віку клієнтів')
plt.xlabel('Вік')
plt.ylabel('Кількість клієнтів')

plt.show()

# %%
sns.countplot(data=df, x='item_purchased', order=df['item_purchased'].value_counts().index)
plt.xticks(rotation=90)  
plt.title('Розподіл покупок за статтею')
plt.xlabel('Стаття')
plt.ylabel('Кількість покупок')
plt.show()

# %%
sns.scatterplot(data=df, x='age', y='purchase_amount_(usd)', hue='purchase_amount_(usd)', s=50)
plt.title('Залежність між віком та сумою покупок')
plt.xlabel('Вік')
plt.ylabel('Сума покупок')
plt.legend(title='Сума покупок')
plt.show()

# %%
sns.histplot(data=df, x='review_rating', bins=10, kde=True, color='skyblue')
plt.title('Розподіл оцінок товарів')
plt.xlabel('Оцінка товару')
plt.ylabel('Кількість оцінок')
plt.show()

# %%
sns.countplot(data=df, x='gender')
plt.title('Розподіл покупок за статтею')
plt.xlabel('Стать')
plt.ylabel('Кількість покупок')
plt.show()

# %%
sns.scatterplot(data=df, x='review_rating', y='purchase_amount_(usd)', hue='purchase_amount_(usd)', s=100)
plt.title('Зв\'язок між рейтингом і сумою покупок')
plt.xlabel('Рейтинг товару')
plt.ylabel('Сума покупок')
plt.legend(title='Сума покупок')
plt.show()

# %%
sns.countplot(data=df, x='season')
plt.title('Сезонність покупок')
plt.xlabel('Сезон')
plt.ylabel('Кількість покупок')
plt.show()

# %%
sns.countplot(data=df, x='size')
plt.title('Розмірність одягу')
plt.xlabel('Розмір')
plt.ylabel('Кількість покупок')
plt.show()

# %%
sns.countplot(data=df, x='payment_method')
plt.xticks(rotation=90)  
plt.title('Методи Оплати')
plt.xlabel('Види оплати')
plt.ylabel('Кількість покупок')
plt.show()

# %%
sns.scatterplot(data=df, x='previous_purchases', y='purchase_amount_(usd)', hue='purchase_amount_(usd)', s=50)
plt.title("Зв'язок між кількістю попередніх покупок та сумою поточної покупки")
plt.xlabel('Кількість попередніх покупок')
plt.ylabel('Сума поточної покупки')
plt.legend(title='Кількість попередніх покупок')
plt.show()

# %% [markdown]
# ## Завдання 2

# %%
import numpy as np
x = np.linspace(-5, 5, 100)
y = np.linspace(-5, 5, 100)
X, Y = np.meshgrid(x, y)
Z = np.sin(np.sqrt(X**2 + Y**2))
fig = plt.figure(figsize=(10, 8))
ax = fig.add_subplot(111, projection='3d')
surf = ax.plot_surface(X, Y, Z, cmap='viridis')
fig.colorbar(surf, shrink=0.5, aspect=5)
ax.set_title('Surface Plot of z = sin(√(x^2 + y^2))')
ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('Z')
plt.show()

# %% [markdown]
# ## Завдання 3

# %%
data_matrix = np.random.rand(5, 5)  
sns.heatmap(data_matrix, annot=True, linewidths=0.5)
plt.title('Графік теплової поверхні')
plt.xlabel('Ось X')
plt.ylabel('Ось Y')

plt.show()
